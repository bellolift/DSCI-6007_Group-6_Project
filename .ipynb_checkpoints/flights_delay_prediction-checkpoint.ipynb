# %%
import pandas as pd
import seaborn as sb
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import roc_auc_score

# %%
flights = pd.read_csv(r'C:\Users\progressive\Downloads\flights.csv')
flights
# Out:
#        MONTH  DAY  SCHEDULED_DEPARTURE  DEPARTURE_DELAY  SCHEDULED_ARRIVAL  \
# 0          4   11                 1715              4.0               1945
# 1         11   27                 1325              2.0               2120
# 2          2   13                  700              5.0                825
# 3          9   13                 1106             -1.0               1106
# 4          2   10                 1631            -16.0               1925
# ...      ...  ...                  ...              ...                ...
# 99995      4   19                 1539            -10.0               2005
# 99996     11   11                  729              5.0                853
# 99997     12    7                 1314              0.0               1613
# 99998      6   19                 1250             -1.0               1525
# 99999      3    8                 1145              1.0               1410
#
#        DIVERTED  CANCELLED  AIR_SYSTEM_DELAY  SECURITY_DELAY  AIRLINE_DELAY  \
# 0             0          0         13.326517        0.080082      18.688681
# 1             0          0         13.326517        0.080082      18.688681
# 2             0          0         13.326517        0.080082      18.688681
# 3             0          0         13.326517        0.080082      18.688681
# 4             0          0         13.326517        0.080082      18.688681
# ...         ...        ...               ...             ...            ...
# 99995         0          0         13.326517        0.080082      18.688681
# 99996         0          0         13.326517        0.080082      18.688681
# 99997         0          0         13.326517        0.080082      18.688681
# 99998         0          0         13.326517        0.080082      18.688681
# 99999         0          0         13.326517        0.080082      18.688681
#
#        LATE_AIRCRAFT_DELAY  WEATHER_DELAY  result
# 0                23.485299       2.933956       0
# 1                23.485299       2.933956       0
# 2                23.485299       2.933956       0
# 3                23.485299       2.933956       0
# 4                23.485299       2.933956       0
# ...                    ...            ...     ...
# 99995            23.485299       2.933956       0
# 99996            23.485299       2.933956       0
# 99997            23.485299       2.933956       0
# 99998            23.485299       2.933956       0
# 99999            23.485299       2.933956       0
#
# [100000 rows x 13 columns]

# %%
flights_needed_data = flights.sample(n=100000)  # getting a segment

# %%
flights_needed_data
# Out:
#        MONTH  DAY  SCHEDULED_DEPARTURE  DEPARTURE_DELAY  SCHEDULED_ARRIVAL  \
# 76208     10   31                 1738            -12.0               2104
# 83368     10    8                 1720             -3.0               1819
# 77312      5    6                 1300              3.0               1627
# 79046      2   10                  800              6.0               1213
# 51576      4   13                 1725             -4.0               1923
# ...      ...  ...                  ...              ...                ...
# 33307      8   26                 2010             -6.0               2140
# 46492      7    8                  505             86.0                728
# 41426      7   28                  901             -4.0               1230
# 72252      1    9                 1445             -2.0               1554
# 58204      2    4                 2030            -11.0               2206
#
#        DIVERTED  CANCELLED  AIR_SYSTEM_DELAY  SECURITY_DELAY  AIRLINE_DELAY  \
# 76208         0          0         13.326517        0.080082      18.688681
# 83368         0          0         13.326517        0.080082      18.688681
# 77312         0          0         13.326517        0.080082      18.688681
# 79046         0          0         13.326517        0.080082      18.688681
# 51576         0          0         13.326517        0.080082      18.688681
# ...         ...        ...               ...             ...            ...
# 33307         0          0         13.326517        0.080082      18.688681
# 46492         0          0          0.000000        0.000000      76.000000
# 41426         0          0         13.326517        0.080082      18.688681
# 72252         0          0         13.326517        0.080082      18.688681
# 58204         0          0         13.326517        0.080082      18.688681
#
#        LATE_AIRCRAFT_DELAY  WEATHER_DELAY  result
# 76208            23.485299       2.933956       0
# 83368            23.485299       2.933956       0
# 77312            23.485299       2.933956       0
# 79046            23.485299       2.933956       0
# 51576            23.485299       2.933956       0
# ...                    ...            ...     ...
# 33307            23.485299       2.933956       0
# 46492             0.000000       0.000000       1
# 41426            23.485299       2.933956       0
# 72252            23.485299       2.933956       0
# 58204            23.485299       2.933956       0
#
# [100000 rows x 13 columns]

# %%
flights_needed_data.info()  # for an insight into the data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100000 entries, 76208 to 58204
# Data columns (total 13 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   MONTH                100000 non-null  int64
#  1   DAY                  100000 non-null  int64
#  2   SCHEDULED_DEPARTURE  100000 non-null  int64
#  3   DEPARTURE_DELAY      100000 non-null  float64
#  4   SCHEDULED_ARRIVAL    100000 non-null  int64
#  5   DIVERTED             100000 non-null  int64
#  6   CANCELLED            100000 non-null  int64
#  7   AIR_SYSTEM_DELAY     100000 non-null  float64
#  8   SECURITY_DELAY       100000 non-null  float64
#  9   AIRLINE_DELAY        100000 non-null  float64
#  10  LATE_AIRCRAFT_DELAY  100000 non-null  float64
#  11  WEATHER_DELAY        100000 non-null  float64
#  12  result               100000 non-null  int64
# dtypes: float64(6), int64(7)
# memory usage: 10.7 MB

# %%
flights_needed_data.value_counts('DIVERTED')  # will tell us the no. of flights which were diverted
# Out:
# DIVERTED
# 0    99745
# 1      255
# dtype: int64

# %%
sb.jointplot(data=flights_needed_data, x="SCHEDULED_ARRIVAL", y="ARRIVAL_TIME")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [7], in <cell line: 1>()
# ----> 1 sb.jointplot(data=flights_needed_data, x="SCHEDULED_ARRIVAL", y="ARRIVAL_TIME")
#
# File ~\anaconda3\lib\site-packages\seaborn\_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# File ~\anaconda3\lib\site-packages\seaborn\axisgrid.py:2230, in jointplot(x, y, data, kind, color, height, ratio, space, dropna, xlim, ylim, marginal_ticks, joint_kws, marginal_kws, hue, palette, hue_order, hue_norm, **kwargs)
#    2227     dropna = True
#    2229 # Initialize the JointGrid object
# -> 2230 grid = JointGrid(
#    2231     data=data, x=x, y=y, hue=hue,
#    2232     palette=palette, hue_order=hue_order, hue_norm=hue_norm,
#    2233     dropna=dropna, height=height, ratio=ratio, space=space,
#    2234     xlim=xlim, ylim=ylim, marginal_ticks=marginal_ticks,
#    2235 )
#    2237 if grid.hue is not None:
#    2238     marginal_kws.setdefault("legend", False)
#
# File ~\anaconda3\lib\site-packages\seaborn\_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# File ~\anaconda3\lib\site-packages\seaborn\axisgrid.py:1702, in JointGrid.__init__(self, x, y, data, height, ratio, space, dropna, xlim, ylim, size, marginal_ticks, hue, palette, hue_order, hue_norm)
#    1699     ax_marg_y.xaxis.grid(False)
#    1701 # Process the input variables
# -> 1702 p = VectorPlotter(data=data, variables=dict(x=x, y=y, hue=hue))
#    1703 plot_data = p.plot_data.loc[:, p.plot_data.notna().any()]
#    1705 # Possibly drop NA
#
# File ~\anaconda3\lib\site-packages\seaborn\_core.py:605, in VectorPlotter.__init__(self, data, variables)
#     603 def __init__(self, data=None, variables={}):
# --> 605     self.assign_variables(data, variables)
#     607     for var, cls in self._semantic_mappings.items():
#     608
#     609         # Create the mapping function
#     610         map_func = partial(cls.map, plotter=self)
#
# File ~\anaconda3\lib\site-packages\seaborn\_core.py:668, in VectorPlotter.assign_variables(self, data, variables)
#     666 else:
#     667     self.input_format = "long"
# --> 668     plot_data, variables = self._assign_variables_longform(
#     669         data, **variables,
#     670     )
#     672 self.plot_data = plot_data
#     673 self.variables = variables
#
# File ~\anaconda3\lib\site-packages\seaborn\_core.py:903, in VectorPlotter._assign_variables_longform(self, data, **kwargs)
#     898 elif isinstance(val, (str, bytes)):
#     899
#     900     # This looks like a column name but we don't know what it means!
#     902     err = f"Could not interpret value `{val}` for parameter `{key}`"
# --> 903     raise ValueError(err)
#     905 else:
#     906
#     907     # Otherwise, assume the value is itself data
#     908
#     909     # Raise when data object is present and a vector can't matched
#     910     if isinstance(data, pd.DataFrame) and not isinstance(val, pd.Series):
#
# ValueError: Could not interpret value `ARRIVAL_TIME` for parameter `y`

# %%
corr = flights_needed_data.corr(method='pearson')

# %%
sb.heatmap(corr)

# %%
corr

# %%
# filtering out unnecessary columns
flights_needed_data=flights_needed_data.drop(['YEAR','FLIGHT_NUMBER','AIRLINE','DISTANCE','TAIL_NUMBER','TAXI_OUT',
                                              'SCHEDULED_TIME','DEPARTURE_TIME','WHEELS_OFF','ELAPSED_TIME',
                                              'AIR_TIME','WHEELS_ON','DAY_OF_WEEK','TAXI_IN','CANCELLATION_REASON'],
                                             axis=1)

# %%
flights_needed_data.reset_index(inplace=True)

# %%
# replacing all NaN values with the mean of the attribute in which they are present
flights_needed_data=flights_needed_data.fillna(flights_needed_data.mean())

# %%
flights_needed_data = flights_needed_data.drop(columns=['index'])
flights_needed_data

# %%
# creating a new column; it will tell if the flight was delayed or not
result=[]

# %%
for row in flights_needed_data['ARRIVAL_DELAY']:
  if row > 15:
    result.append(1)
  else:
    result.append(0)

# %%
flights_needed_data['result'] = result

# %%
flights_needed_data

# %%
flights_needed_data.value_counts('result')

# %%
# removing some more columns
flights_needed_data=flights_needed_data.drop(['ORIGIN_AIRPORT', 'DESTINATION_AIRPORT', 'ARRIVAL_TIME', 'ARRIVAL_DELAY'],axis=1)
flights_needed_data

# %%
data = flights_needed_data
X, y = data.iloc[:,:-1], data.iloc[:,-1]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42,stratify=y)  # splitting in the ratio 70:30

# %%
flights_needed_data.to_csv(r'C:\Users\progressive\Downloads\flights.csv',index=False, header=True)

# %%
X_train
# Out:
#        MONTH  DAY  SCHEDULED_DEPARTURE  DEPARTURE_DELAY  SCHEDULED_ARRIVAL  \
# 17463      6   29                 1650         7.000000               1915
# 50879     12    9                 1640         9.206685               1914
# 18896      6   24                 1345        28.000000               2159
# 73714      5    1                 2000        83.000000               2313
# 89285      6    6                 1105        -7.000000               1648
# ...      ...  ...                  ...              ...                ...
# 12158     11    1                 1300        -2.000000               1410
# 91954      8   27                  846         0.000000               1018
# 74305     12   15                 1508        -4.000000               1819
# 57749     12   26                  600        -4.000000                925
# 21791     12   19                  900       -12.000000               1010
#
#        DIVERTED  CANCELLED  AIR_SYSTEM_DELAY  SECURITY_DELAY  AIRLINE_DELAY  \
# 17463         0          0         13.326517        0.080082      18.688681
# 50879         0          1         13.326517        0.080082      18.688681
# 18896         0          0         13.326517        0.080082      18.688681
# 73714         0          0          3.000000        0.000000       1.000000
# 89285         0          0         13.326517        0.080082      18.688681
# ...         ...        ...               ...             ...            ...
# 12158         0          0         13.326517        0.080082      18.688681
# 91954         0          0         13.326517        0.080082      18.688681
# 74305         0          0         13.326517        0.080082      18.688681
# 57749         0          0         38.000000        0.000000       0.000000
# 21791         0          0         13.326517        0.080082      18.688681
#
#        LATE_AIRCRAFT_DELAY  WEATHER_DELAY
# 17463            23.485299       2.933956
# 50879            23.485299       2.933956
# 18896            23.485299       2.933956
# 73714            82.000000       0.000000
# 89285            23.485299       2.933956
# ...                    ...            ...
# 12158            23.485299       2.933956
# 91954            23.485299       2.933956
# 74305            23.485299       2.933956
# 57749             0.000000       0.000000
# 21791            23.485299       2.933956
#
# [70000 rows x 12 columns]

# %%
clf = DecisionTreeClassifier()
clf = clf.fit(X_train,y_train)

# %%
pred = clf.predict(X_test)
pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
X_test.head()
# Out:
#        MONTH  DAY  SCHEDULED_DEPARTURE  DEPARTURE_DELAY  SCHEDULED_ARRIVAL  \
# 38647      6   17                 1040              1.0               1254
# 24108      7   23                  812              4.0               1132
# 99142     10   15                  845              0.0                948
# 27337     10   22                 2100              0.0                 25
# 29344     11   10                 1550              8.0               1800
#
#        DIVERTED  CANCELLED  AIR_SYSTEM_DELAY  SECURITY_DELAY  AIRLINE_DELAY  \
# 38647         0          0         13.326517        0.080082      18.688681
# 24108         0          0         13.326517        0.080082      18.688681
# 99142         0          0         13.326517        0.080082      18.688681
# 27337         0          0         13.326517        0.080082      18.688681
# 29344         0          0          8.000000        0.000000       8.000000
#
#        LATE_AIRCRAFT_DELAY  WEATHER_DELAY
# 38647            23.485299       2.933956
# 24108            23.485299       2.933956
# 99142            23.485299       2.933956
# 27337            23.485299       2.933956
# 29344             0.000000       0.000000

# %%
# X_test.AIR_SYSTEM_DELAY.min()
X_test.SCHEDULED_DEPARTURE.min()
# Out:
# 5

# %%
X_test.columns
# X_test.info()
# Out:
# Index(['MONTH', 'DAY', 'SCHEDULED_DEPARTURE', 'DEPARTURE_DELAY',
#        'SCHEDULED_ARRIVAL', 'DIVERTED', 'CANCELLED', 'AIR_SYSTEM_DELAY',
#        'SECURITY_DELAY', 'AIRLINE_DELAY', 'LATE_AIRCRAFT_DELAY',
#        'WEATHER_DELAY'],
#       dtype='object')

# %%
trsh = pd.DataFrame(columns=['MONTH', 'DAY', 'SCHEDULED_DEPARTURE', 'DEPARTURE_DELAY',
       'SCHEDULED_ARRIVAL', 'DIVERTED', 'CANCELLED', 'AIR_SYSTEM_DELAY',
       'SECURITY_DELAY', 'AIRLINE_DELAY', 'LATE_AIRCRAFT_DELAY',
       'WEATHER_DELAY'])

# %%
trsh
# Out:
# Empty DataFrame
# Columns: [MONTH, DAY, SCHEDULED_DEPARTURE, DEPARTURE_DELAY, SCHEDULED_ARRIVAL, DIVERTED, CANCELLED, AIR_SYSTEM_DELAY, SECURITY_DELAY, AIRLINE_DELAY, LATE_AIRCRAFT_DELAY, WEATHER_DELAY]
# Index: []

# %%
pred_prob = clf.predict_proba(X_test)
auc_score = roc_auc_score(y_test, pred_prob[:,1])
auc_score
# Out:
# 0.996769987108999

# %%
x = pd.read_csv(r'C:\Users\progressive\Downloads\flights.csv').iloc[:,1:]
x.head()
pd.io.sql.get_schema(x.reset_index(), 'data')
# Out:
# 'CREATE TABLE "data" (\n"index" INTEGER,\n  "DAY" INTEGER,\n  "SCHEDULED_DEPARTURE" INTEGER,\n  "DEPARTURE_DELAY" REAL,\n  "SCHEDULED_ARRIVAL" INTEGER,\n  "DIVERTED" INTEGER,\n  "CANCELLED" INTEGER,\n  "AIR_SYSTEM_DELAY" REAL,\n  "SECURITY_DELAY" REAL,\n  "AIRLINE_DELAY" REAL,\n  "LATE_AIRCRAFT_DELAY" REAL,\n  "WEATHER_DELAY" REAL,\n  "result" INTEGER\n)'

# %%
flights_needed_data.head()
# Out:
#        MONTH  DAY  SCHEDULED_DEPARTURE  DEPARTURE_DELAY  SCHEDULED_ARRIVAL  \
# 76208     10   31                 1738            -12.0               2104
# 83368     10    8                 1720             -3.0               1819
# 77312      5    6                 1300              3.0               1627
# 79046      2   10                  800              6.0               1213
# 51576      4   13                 1725             -4.0               1923
#
#        DIVERTED  CANCELLED  AIR_SYSTEM_DELAY  SECURITY_DELAY  AIRLINE_DELAY  \
# 76208         0          0         13.326517        0.080082      18.688681
# 83368         0          0         13.326517        0.080082      18.688681
# 77312         0          0         13.326517        0.080082      18.688681
# 79046         0          0         13.326517        0.080082      18.688681
# 51576         0          0         13.326517        0.080082      18.688681
#
#        LATE_AIRCRAFT_DELAY  WEATHER_DELAY  result
# 76208            23.485299       2.933956       0
# 83368            23.485299       2.933956       0
# 77312            23.485299       2.933956       0
# 79046            23.485299       2.933956       0
# 51576            23.485299       2.933956       0
